# %%
pip install gymnasium
# Out:
# Collecting gymnasium
#   Downloading gymnasium-1.0.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Downloading gymnasium-1.0.0-py3-none-any.whl (958 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 958.1/958.1 kB 8.3 MB/s eta 0:00:00
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, gymnasium
# Successfully installed farama-notifications-0.0.4 gymnasium-1.0.0

# %%
import numpy as np
import torch
from tqdm import tqdm
from gymnasium.wrappers import TimeLimit
import gymnasium as gym
from statistics import mean
from functools import partial
from typing import Protocol
import random
import os
from pathlib import Path
from copy import deepcopy
import torch.nn as nn
from sklearn.ensemble import RandomForestRegressor
import pickle

# %%
from google.colab import drive
drive.mount('/content/drive')

# Access the specific folder in your MyDrive
path = '/content/drive/MyDrive/MVA/'
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 1 - Environment for HIV Patient

# %% [markdown]
# Imported all code from src/env_hiv.py

# %%
class HIVPatient(gym.Env):
    """HIV patient simulator

    Implements the simulator defined in 'Dynamic Multidrug Therapies for HIV: Optimal and STI Control Approaches' by Adams et al. (2004).
    The transition() function allows to simulate continuous time dynamics and control.
    The step() function is tailored for the evaluation of Structured Treatment Interruptions.
    """

    def __init__(
        self, clipping=True, logscale=False, domain_randomization: bool = False
    ):
        super(HIVPatient, self).__init__()

        self.domain_randomization = domain_randomization
        self.action_space = gym.spaces.Discrete(4)
        self.observation_space = gym.spaces.Box(
            shape=(6,), low=-np.inf, high=np.inf, dtype=np.float32
        )

        self.T1 = 163573.0  # healthy type 1 cells concentration (cells per mL)
        self.T1star = 11945.0  # infected type 1 cells concentration (cells per mL)
        self.T2 = 5.0  # healthy type 2 cells concentration (cells per mL)
        self.T2star = 46.0  # infected type 2 cells concentration (cells per mL)
        self.V = 63919.0  # free virus (copies per mL)
        self.E = 24.0  # immune effector cells concentration (cells per mL)

        # actions
        self.action_set = [
            np.array(pair) for pair in [[0.0, 0.0], [0.0, 0.3], [0.7, 0.0], [0.7, 0.3]]
        ]

        self._reset_patient_parameters()

        # action bounds
        self.a1 = 0.0  # lower bound on reverse transcriptase efficacy
        self.b1 = 0.7  # lower bound on reverse transcriptase efficacy
        self.a2 = 0.0  # lower bound on protease inhibitor efficacy
        self.b2 = 0.3  # lower bound on protease inhibitor efficacy

        # reward model
        self.Q = 0.1
        self.R1 = 20000.0
        self.R2 = 20000.0
        self.S = 1000.0

        # options
        self.clipping = clipping  # clip the state to the upper and lower bounds (affects the state attributes, which are clipped before being stored in T1, T1star, etc.)
        self.logscale = logscale  # convert state to log10-scale before returning (does not affect the state attributes, which remain stored without the log10 operation)
        self.T1Upper = 1e6
        self.T1starUpper = 5e4
        self.T2Upper = 3200.0
        self.T2starUpper = 80.0
        self.VUpper = 2.5e5
        self.EUpper = 353200.0
        self.upper = np.array(
            [
                self.T1Upper,
                self.T1starUpper,
                self.T2Upper,
                self.T2starUpper,
                self.VUpper,
                self.EUpper,
            ]
        )
        self.T1Lower = 0.0
        self.T1starLower = 0.0
        self.T2Lower = 0.0
        self.T2starLower = 0.0
        self.VLower = 0.0
        self.ELower = 0.0
        self.lower = np.array(
            [
                self.T1Lower,
                self.T1starLower,
                self.T2Lower,
                self.T2starLower,
                self.VLower,
                self.ELower,
            ]
        )

    def rawstate(self):
        return np.array([self.T1, self.T1star, self.T2, self.T2star, self.V, self.E])

    def state(self):
        s = np.array([self.T1, self.T1star, self.T2, self.T2star, self.V, self.E])
        if self.clipping:
            np.clip(s, self.lower, self.upper, out=s)
        if self.logscale:
            s = np.log10(s)
        return s

    def _reset_patient_parameters(self):
        if self.domain_randomization:
            # randomly changing patient parameters
            self.k1 = np.random.uniform(low=5e-7, high=8e-7)
            # cell2
            self.k2 = np.random.uniform(low=0.1e-4, high=1.0e-4)
            self.f = np.random.uniform(low=0.29, high=0.34)

        else:

            self.k1 = 8e-7  # infection rate (mL per virions and per day)

            self.k2 = 1e-4  # infection rate (mL per virions and per day)
            self.f = 0.34  # treatment efficacy reduction for type 2 cells
        # patient parameters

        # cell type 1
        self.lambda1 = 1e4  # production rate (cells per mL and per day)
        self.d1 = 1e-2  # death rate (per day)
        self.m1 = 1e-5  # immune-induced clearance rate (mL per cells and per day)
        self.rho1 = 1  # nb virions infecting a cell (virions per cell)

        # cell type 2
        self.lambda2 = 31.98  # production rate (cells per mL and per day)
        self.d2 = 1e-2  # death rate (per day)
        self.m2 = 1e-5  # immune-induced clearance rate (mL per cells and per day)
        self.rho2 = 1  # nb virions infecting a cell (virions per cell)
        # infected cells
        self.delta = 0.7  # death rate (per day)
        self.NT = 100  # virions produced (virions per cell)
        self.c = 13  # virus natural death rate (per day)
        # immune response (immune effector cells)
        self.lambdaE = 1  # production rate (cells per mL and per day)
        self.bE = 0.3  # maximum birth rate (per day)
        self.Kb = 100  # saturation constant for birth (cells per mL)
        self.dE = 0.25  # maximum death rate (per day)
        self.Kd = 500  # saturation constant for death (cells per mL)
        self.deltaE = 0.1  # natural death rate (per day)

    def reset(
        self, *, seed: int | None = None, options: dict | None = None, mode="unhealthy"
    ):
        if mode == "uninfected":
            self.T1 = 1e6
            self.T1star = 0.0
            self.T2 = 3198.0
            self.T2star = 0.0
            self.V = 0.0
            self.E = 10.0
        elif mode == "unhealthy":
            self.T1 = 163573.0
            self.T1star = 11945.0
            self.T2 = 5.0
            self.T2star = 46.0
            self.V = 63919.0
            self.E = 24.0
        elif mode == "healthy":
            self.T1 = 967839.0
            self.T1star = 76.0
            self.T2 = 621.0
            self.T2star = 6.0
            self.V = 415.0
            self.E = 353108.0
        else:
            print("Patient mode '", mode, "' unrecognized. State unchanged.")

        self._reset_patient_parameters()

        return self.state(), {}

    def der(self, state, action):
        T1 = state[0]
        T1star = state[1]
        T2 = state[2]
        T2star = state[3]
        V = state[4]
        E = state[5]

        eps1 = action[0]
        eps2 = action[1]

        T1dot = self.lambda1 - self.d1 * T1 - self.k1 * (1 - eps1) * V * T1

        T1stardot = (
            self.k1 * (1 - eps1) * V * T1 - self.delta * T1star - self.m1 * E * T1star
        )
        T2dot = self.lambda2 - self.d2 * T2 - self.k2 * (1 - self.f * eps1) * V * T2
        T2stardot = (
            self.k2 * (1 - self.f * eps1) * V * T2
            - self.delta * T2star
            - self.m2 * E * T2star
        )
        Vdot = (
            self.NT * self.delta * (1 - eps2) * (T1star + T2star)
            - self.c * V
            - (
                self.rho1 * self.k1 * (1 - eps1) * T1
                + self.rho2 * self.k2 * (1 - self.f * eps1) * T2
            )
            * V
        )
        Edot = (
            self.lambdaE
            + self.bE * (T1star + T2star) * E / (T1star + T2star + self.Kb)
            - self.dE * (T1star + T2star) * E / (T1star + T2star + self.Kd)
            - self.deltaE * E
        )
        return np.array([T1dot, T1stardot, T2dot, T2stardot, Vdot, Edot])

    def transition(self, state, action, duration):
        """duration should be a multiple of 1e-3"""
        state0 = np.copy(state)
        state0_orig = np.copy(state)
        nb_steps = int(duration // 1e-3)
        for i in range(nb_steps):
            der = self.der(state0, action)
            state1 = state0 + der * 1e-3

            # np.clip(state1, self.lower, self.upper, out=state1)
            state0 = state1
        return state1

    def reward(self, state, action, state2):
        rew = -(
            self.Q * state[4]
            + self.R1 * action[0] ** 2
            + self.R2 * action[1] ** 2
            - self.S * state[5]
        )
        return rew

    def step(self, a_index):
        state = self.state()
        action = self.action_set[a_index]
        state2 = self.transition(state, action, 5)
        rew = self.reward(state, action, state2)
        if self.clipping:
            np.clip(state2, self.lower, self.upper, out=state2)

        self.T1 = state2[0]
        self.T1star = state2[1]
        self.T2 = state2[2]
        self.T2star = state2[3]
        self.V = state2[4]
        self.E = state2[5]

        if self.logscale:
            state2 = np.log10(state2)

        return state2, rew, False, False, {}



class Agent(Protocol):
    """
    Defines an interface for agents in a simulation or decision-making environment.

    An Agent must implement methods to act based on observations, save its state to a file,
    and load its state from a file. This interface uses the Protocol class from the typing
    module to specify methods that concrete classes must implement.

    Protocols are a way to define formal Python interfaces. They allow for type checking
    and ensure that implementing classes provide specific methods with the expected signatures.
    """

    def act(self, observation: np.ndarray, use_random: bool = False) -> int:
        """
        Determines the next action based on the current observation from the environment.

        Implementing this method requires processing the observation and optionally incorporating
        randomness into the decision-making process (e.g., for exploration in reinforcement learning).

        Args:
            observation (np.ndarray): The current environmental observation that the agent must use
                                       to decide its next action. This array typically represents
                                       the current state of the environment.
            use_random (bool, optional): A flag to indicate whether the agent should make a random
                                         decision. This is often used for exploration. Defaults to False.

        Returns:
            int: The action to be taken by the agent.
        """
        pass

    def save(self, path: str) -> None:
        """
        Saves the agent's current state to a file specified by the path.

        This method should serialize the agent's state (e.g., model weights, configuration settings)
        and save it to a file, allowing the agent to be later restored to this state using the `load` method.

        Args:
            path (str): The file path where the agent's state should be saved.

        """
        pass

    def load(self) -> None:
        """
        Loads the agent's state from a file specified by the path (HARDCODED). This not a good practice,
        but it will simplify the grading process.

        This method should deserialize the saved state (e.g., model weights, configuration settings)
        from the file and restore the agent to this state. Implementations must ensure that the
        agent's state is compatible with the `act` method's expectations.

        Note:
            It's important to ensure that neural network models (if used) are loaded in a way that is
            compatible with the execution device (e.g., CPU, GPU). This may require specific handling
            depending on the libraries used for model implementation. WARNING: THE GITHUB CLASSROOM
        HANDLES ONLY CPU EXECUTION. IF YOU USE A NEURAL NETWORK MODEL, MAKE SURE TO LOAD IT IN A WAY THAT
        DOES NOT REQUIRE A GPU.
        """
        pass




def evaluate_agent(agent: Agent, env: gym.Env, nb_episode: int = 10) -> float:
    """
    Evaluate an agent in a given environment.

    Args:
        agent (Agent): The agent to evaluate.
        env (gym.Env): The environment to evaluate the agent in.
        nb_episode (int): The number of episode to evaluate the agent.

    Returns:
        float: The mean reward of the agent over the episodes.
    """
    rewards: list[float] = []
    for _ in range(nb_episode):
        obs, info = env.reset()
        done = False
        truncated = False
        episode_reward = 0
        while not done and not truncated:
            action = agent.act(obs)
            obs, reward, done, truncated, _ = env.step(action)
            episode_reward += reward
        rewards.append(episode_reward)
    return mean(rewards)


evaluate_HIV = partial(
    evaluate_agent, env=TimeLimit(HIVPatient(), max_episode_steps=200)
)


evaluate_HIV_population = partial(
    evaluate_agent,
    env=TimeLimit(HIVPatient(domain_randomization=True), max_episode_steps=200),
)

# %%
# Environment setup with a time limit of 200 steps per episode
env = TimeLimit(env=HIVPatient(domain_randomization=True), max_episode_steps=200)

# %% [markdown]
# # 2 - Tools functions for the training

# %% [markdown]
# # Picking Greedy Action with respect to Q
# (from course RL4)

# %% [markdown]
# ## Replay Buffer
# (from course RL4)

# %%
class ReplayBuffer:
    def __init__(self, capacity, device):
        self.capacity = capacity
        self.data = []
        self.index = 0
        self.device = device
    def append(self, s, a, r, s_, d):
        if len(self.data) < self.capacity:
            self.data.append(None)
        self.data[self.index] = (s, a, r, s_, d)
        self.index = (self.index + 1) % self.capacity
    def sample(self, batch_size):
        batch = random.sample(self.data, batch_size)
        return list(map(lambda x:torch.Tensor(np.array(x)).to(self.device), list(zip(*batch))))
    def __len__(self):
        return len(self.data)

# %% [markdown]
# ## DQN Architecture

# %% [markdown]
# Used MLP fully connected with ReLU() for the architecutre. \\
# Final architecture : 6 layers of size 256.

# %%
hidden_layer_dim = 256
inner_dim = 128

DQN = torch.nn.Sequential(
            torch.nn.Linear(env.observation_space.shape[0], hidden_layer_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(hidden_layer_dim, hidden_layer_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(hidden_layer_dim, inner_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(inner_dim, inner_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(inner_dim, hidden_layer_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(hidden_layer_dim, hidden_layer_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(hidden_layer_dim, env.action_space.n)
)

# %% [markdown]
# # 3 - Agent Definition

# %% [markdown]
# Agent construction method and train method are highly inspired from the implementation of the DQN with target network provided in the solution of course RL4 (CartPole exemple).
#
# I added to this implementation the following improvements :
#
# *   Deeper architecture for the DQN
# *   Chose best hyperparameters for this architecture after a few runs
# *   Tried with RMSProp optimizer, but better results with Adam

# %%
# ProjectAgent class to define agent logic
class ProjectAgent:
    def __init__(self):
        # Configuration for the agent
        self.nb_actions = env.action_space.n
        self.learning_rate = 0.0001
        self.gamma = 0.95
        self.buffer_size = 50000
        self.epsilon_min = 0.01
        self.epsilon_max = 1.0
        self.epsilon_decay_period = 50000
        self.epsilon_delay_decay = 1000
        self.epsilon_delay = 100
        self.epsilon_step = (self.epsilon_max - self.epsilon_min) / self.epsilon_decay_period
        self.batch_size = 1024
        self.gradient_steps = 10
        self.update_target_strategy = 'replace'
        self.update_target_freq = 500
        self.update_target_tau = 0.01
        self.criterion = torch.nn.SmoothL1Loss()
        self.fine_tuning = False

        # Linking first the models to GPU device
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        if not self.fine_tuning:
            self.model = DQN.to(self.device)
        self.target_model = deepcopy(self.model).to(self.device)
        self.memory = ReplayBuffer(self.buffer_size, self.device)

        # Choice of optimizers for both networks : Adams
        self.optimizer = torch.optim.AdamW(self.model.parameters(), lr=self.learning_rate)

    def act(self, observation, use_random=False):
        # Acting greedily towards Q
        with torch.no_grad():  # Disable gradient computation for action selection
            Q = self.model(torch.Tensor(observation).unsqueeze(0).to(self.device))
            return torch.argmax(Q).item()


    def save(self, path):
        self.path = path + "final_dqn.pt"
        torch.save(self.model.state_dict(), self.path)

    def load(self):
        self.path = path + "final_dqn.pt"
        self.model = DQN.to(self.device)
        self.model.load_state_dict(torch.load(self.path, map_location=self.device))
        self.model.eval()

    def train(self, max_episode):
        previous_val = 0
        episode_return = []
        episode = 0
        episode_cum_reward = 0
        state, _ = env.reset()
        epsilon = self.epsilon_max
        step = 0

        while episode < max_episode:
            # Decay epsilon after a certain number of steps
            if step > self.epsilon_delay:
                epsilon = max(self.epsilon_min, epsilon - self.epsilon_step)

            # Action selection (epsilon-greedy)
            if np.random.rand() < epsilon:
                action = env.action_space.sample()  # Exploration
            else:
                action = self.act(state)  # Exploitation

            # Take action, observe result
            next_state, reward, done, trunc, _ = env.step(action)
            self.memory.append(state, action, reward, next_state, done)
            episode_cum_reward += reward

            # Train the model
            for _ in range(self.gradient_steps):
                if len(self.memory) > self.batch_size:
                    X, A, R, Y, D = self.memory.sample(self.batch_size)
                    QYmax = self.target_model(Y).max(1)[0].detach()
                    update = torch.addcmul(R, 1 - D, QYmax, value=self.gamma)
                    QXA = self.model(X).gather(1, A.to(torch.long).unsqueeze(1))
                    loss = self.criterion(QXA, update.unsqueeze(1))
                    self.optimizer.zero_grad()
                    loss.backward()
                    self.optimizer.step()

            # Update target model periodically
            if self.update_target_strategy == 'replace':
                if step % self.update_target_freq == 0:
                    self.target_model.load_state_dict(self.model.state_dict())

            step += 1
            if done or trunc:
                episode += 1
                val_score = evaluate_HIV(agent=self, nb_episode=1)

                # Print training progress
                print(f"Episode {episode:3d} | "
                      f"Epsilon {epsilon:6.2f} | "
                      f"Batch Size {len(self.memory):5d} | "
                      f"Episode Return {episode_cum_reward:.2e} | "
                      f"Evaluation Score {val_score:.2e}")
                state, _ = env.reset()

                # Save model if evaluation score improves
                if val_score > previous_val:
                    previous_val = val_score
                    self.best_model = deepcopy(self.model).to(self.device)
                    path = os.getcwd()
                    self.save(path)
                episode_return.append(episode_cum_reward)
                episode_cum_reward = 0
            else:
                state = next_state

        # Load the best model and save it
        self.model.load_state_dict(self.best_model.state_dict())
        path = os.getcwd()
        self.save(path)
        return episode_return

def seed_everything(seed: int = 42):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    torch.cuda.manual_seed_all(seed)

# %%
if __name__ == "__main__":
    file = Path("score.txt")
    if not file.is_file():
        seed_everything(seed=42)
        # Initialization of the agent. Replace DummyAgent with your custom agent implementation.
        agent = ProjectAgent()
        agent.train(500)
        agent.save(path)

        # Evaluate agent and write score.
        score_agent: float = evaluate_HIV(agent=agent, nb_episode=5)
        score_agent_dr: float = evaluate_HIV_population(agent=agent, nb_episode=20)
        print(f"Score agent: {score_agent}")
        print(f"Score agent with domain randomization: {score_agent_dr}")
        with open(file= path + "score.txt", mode="w") as f:
            f.write(f"{score_agent}\n{score_agent_dr}")
# Out:
# Episode   1 | Epsilon   1.00 | Batch Size   200 | Episode Return 1.21e+07 | Evaluation Score 3.43e+06
# Episode   2 | Epsilon   0.99 | Batch Size   400 | Episode Return 9.11e+06 | Evaluation Score 3.43e+06
# Episode   3 | Epsilon   0.99 | Batch Size   600 | Episode Return 6.14e+06 | Evaluation Score 3.43e+06
# Episode   4 | Epsilon   0.99 | Batch Size   800 | Episode Return 8.89e+06 | Evaluation Score 3.43e+06
# Episode   5 | Epsilon   0.98 | Batch Size  1000 | Episode Return 1.31e+07 | Evaluation Score 3.43e+06
# Episode   6 | Epsilon   0.98 | Batch Size  1200 | Episode Return 7.49e+06 | Evaluation Score 3.43e+06
# Episode   7 | Epsilon   0.97 | Batch Size  1400 | Episode Return 5.86e+06 | Evaluation Score 3.43e+06
# Episode   8 | Epsilon   0.97 | Batch Size  1600 | Episode Return 8.90e+06 | Evaluation Score 3.43e+06
# Episode   9 | Epsilon   0.97 | Batch Size  1800 | Episode Return 8.13e+06 | Evaluation Score 3.43e+06
# Episode  10 | Epsilon   0.96 | Batch Size  2000 | Episode Return 1.13e+07 | Evaluation Score 3.43e+06
# Episode  11 | Epsilon   0.96 | Batch Size  2200 | Episode Return 6.47e+06 | Evaluation Score 2.13e+07
# Episode  12 | Epsilon   0.95 | Batch Size  2400 | Episode Return 9.65e+06 | Evaluation Score 6.59e+07
# Episode  13 | Epsilon   0.95 | Batch Size  2600 | Episode Return 7.51e+06 | Evaluation Score 6.78e+07
# Episode  14 | Epsilon   0.95 | Batch Size  2800 | Episode Return 9.16e+06 | Evaluation Score 4.13e+07
# Episode  15 | Epsilon   0.94 | Batch Size  3000 | Episode Return 1.23e+07 | Evaluation Score 2.42e+07
# Episode  16 | Epsilon   0.94 | Batch Size  3200 | Episode Return 8.03e+06 | Evaluation Score 1.06e+07
# Episode  17 | Epsilon   0.93 | Batch Size  3400 | Episode Return 1.10e+07 | Evaluation Score 1.06e+07
# Episode  18 | Epsilon   0.93 | Batch Size  3600 | Episode Return 1.27e+07 | Evaluation Score 1.06e+07
# Episode  19 | Epsilon   0.93 | Batch Size  3800 | Episode Return 6.84e+06 | Evaluation Score 8.30e+06
# Episode  20 | Epsilon   0.92 | Batch Size  4000 | Episode Return 1.12e+07 | Evaluation Score 8.08e+06
# Episode  21 | Epsilon   0.92 | Batch Size  4200 | Episode Return 7.54e+06 | Evaluation Score 8.54e+06
# Episode  22 | Epsilon   0.91 | Batch Size  4400 | Episode Return 8.30e+06 | Evaluation Score 8.84e+06
# Episode  23 | Epsilon   0.91 | Batch Size  4600 | Episode Return 4.35e+06 | Evaluation Score 8.85e+06
# Episode  24 | Epsilon   0.91 | Batch Size  4800 | Episode Return 1.18e+07 | Evaluation Score 8.89e+06
# Episode  25 | Epsilon   0.90 | Batch Size  5000 | Episode Return 7.02e+06 | Evaluation Score 8.00e+06
# Episode  26 | Epsilon   0.90 | Batch Size  5200 | Episode Return 7.27e+06 | Evaluation Score 7.68e+06
# Episode  27 | Epsilon   0.90 | Batch Size  5400 | Episode Return 1.12e+07 | Evaluation Score 8.40e+06
# Episode  28 | Epsilon   0.89 | Batch Size  5600 | Episode Return 1.15e+07 | Evaluation Score 7.78e+06
# Episode  29 | Epsilon   0.89 | Batch Size  5800 | Episode Return 1.16e+07 | Evaluation Score 8.23e+06
# Episode  30 | Epsilon   0.88 | Batch Size  6000 | Episode Return 8.00e+06 | Evaluation Score 7.63e+06
# Episode  31 | Epsilon   0.88 | Batch Size  6200 | Episode Return 1.55e+07 | Evaluation Score 7.89e+06
# Episode  32 | Epsilon   0.88 | Batch Size  6400 | Episode Return 1.95e+07 | Evaluation Score 8.19e+06
# Episode  33 | Epsilon   0.87 | Batch Size  6600 | Episode Return 1.00e+07 | Evaluation Score 9.70e+06
# Episode  34 | Epsilon   0.87 | Batch Size  6800 | Episode Return 1.12e+07 | Evaluation Score 9.68e+06
# Episode  35 | Epsilon   0.86 | Batch Size  7000 | Episode Return 7.63e+06 | Evaluation Score 9.89e+06
# Episode  36 | Epsilon   0.86 | Batch Size  7200 | Episode Return 7.22e+06 | Evaluation Score 9.12e+06
# Episode  37 | Epsilon   0.86 | Batch Size  7400 | Episode Return 5.52e+06 | Evaluation Score 8.47e+06
# Episode  38 | Epsilon   0.85 | Batch Size  7600 | Episode Return 6.03e+06 | Evaluation Score 8.35e+06
# Episode  39 | Epsilon   0.85 | Batch Size  7800 | Episode Return 1.56e+07 | Evaluation Score 8.52e+06
# Episode  40 | Epsilon   0.84 | Batch Size  8000 | Episode Return 9.13e+06 | Evaluation Score 8.41e+06
# Episode  41 | Epsilon   0.84 | Batch Size  8200 | Episode Return 9.34e+06 | Evaluation Score 8.51e+06
# Episode  42 | Epsilon   0.84 | Batch Size  8400 | Episode Return 6.26e+06 | Evaluation Score 8.95e+06
# Episode  43 | Epsilon   0.83 | Batch Size  8600 | Episode Return 1.26e+07 | Evaluation Score 7.76e+06
# Episode  44 | Epsilon   0.83 | Batch Size  8800 | Episode Return 8.29e+06 | Evaluation Score 9.08e+06
# Episode  45 | Epsilon   0.82 | Batch Size  9000 | Episode Return 1.55e+07 | Evaluation Score 8.64e+06
# Episode  46 | Epsilon   0.82 | Batch Size  9200 | Episode Return 1.06e+07 | Evaluation Score 7.26e+06
# Episode  47 | Epsilon   0.82 | Batch Size  9400 | Episode Return 2.05e+07 | Evaluation Score 7.41e+06
# Episode  48 | Epsilon   0.81 | Batch Size  9600 | Episode Return 1.69e+07 | Evaluation Score 9.01e+06
# Episode  49 | Epsilon   0.81 | Batch Size  9800 | Episode Return 2.59e+07 | Evaluation Score 1.02e+07
# Episode  50 | Epsilon   0.80 | Batch Size 10000 | Episode Return 1.57e+07 | Evaluation Score 9.91e+06
# Episode  51 | Epsilon   0.80 | Batch Size 10200 | Episode Return 7.65e+06 | Evaluation Score 9.27e+06
# Episode  52 | Epsilon   0.80 | Batch Size 10400 | Episode Return 1.12e+07 | Evaluation Score 9.29e+06
# Episode  53 | Epsilon   0.79 | Batch Size 10600 | Episode Return 1.14e+07 | Evaluation Score 9.38e+06
# Episode  54 | Epsilon   0.79 | Batch Size 10800 | Episode Return 1.37e+07 | Evaluation Score 1.02e+07
# Episode  55 | Epsilon   0.78 | Batch Size 11000 | Episode Return 1.41e+07 | Evaluation Score 1.05e+07
# Episode  56 | Epsilon   0.78 | Batch Size 11200 | Episode Return 1.27e+07 | Evaluation Score 1.08e+07
# Episode  57 | Epsilon   0.78 | Batch Size 11400 | Episode Return 1.97e+07 | Evaluation Score 1.08e+07
# Episode  58 | Epsilon   0.77 | Batch Size 11600 | Episode Return 9.82e+06 | Evaluation Score 9.82e+06
# Episode  59 | Epsilon   0.77 | Batch Size 11800 | Episode Return 1.21e+07 | Evaluation Score 1.03e+07
# Episode  60 | Epsilon   0.76 | Batch Size 12000 | Episode Return 1.14e+07 | Evaluation Score 9.11e+06
# Episode  61 | Epsilon   0.76 | Batch Size 12200 | Episode Return 2.48e+07 | Evaluation Score 9.72e+06
# Episode  62 | Epsilon   0.76 | Batch Size 12400 | Episode Return 1.15e+07 | Evaluation Score 9.89e+06
# Episode  63 | Epsilon   0.75 | Batch Size 12600 | Episode Return 1.30e+07 | Evaluation Score 1.02e+07
# Episode  64 | Epsilon   0.75 | Batch Size 12800 | Episode Return 1.74e+07 | Evaluation Score 1.05e+07
# Episode  65 | Epsilon   0.74 | Batch Size 13000 | Episode Return 1.16e+07 | Evaluation Score 1.05e+07
# Episode  66 | Epsilon   0.74 | Batch Size 13200 | Episode Return 1.56e+07 | Evaluation Score 1.02e+07
# Episode  67 | Epsilon   0.74 | Batch Size 13400 | Episode Return 2.33e+07 | Evaluation Score 1.07e+07
# Episode  68 | Epsilon   0.73 | Batch Size 13600 | Episode Return 1.49e+07 | Evaluation Score 1.02e+07
# Episode  69 | Epsilon   0.73 | Batch Size 13800 | Episode Return 2.01e+07 | Evaluation Score 1.02e+07
# Episode  70 | Epsilon   0.72 | Batch Size 14000 | Episode Return 2.16e+07 | Evaluation Score 1.07e+07
# Episode  71 | Epsilon   0.72 | Batch Size 14200 | Episode Return 3.42e+07 | Evaluation Score 1.04e+07
# Episode  72 | Epsilon   0.72 | Batch Size 14400 | Episode Return 2.71e+07 | Evaluation Score 1.04e+07
# Episode  73 | Epsilon   0.71 | Batch Size 14600 | Episode Return 1.53e+07 | Evaluation Score 8.82e+06
# Episode  74 | Epsilon   0.71 | Batch Size 14800 | Episode Return 2.18e+07 | Evaluation Score 9.44e+06
# Episode  75 | Epsilon   0.70 | Batch Size 15000 | Episode Return 2.29e+07 | Evaluation Score 8.77e+06
# Episode  76 | Epsilon   0.70 | Batch Size 15200 | Episode Return 1.60e+07 | Evaluation Score 8.95e+06
# Episode  77 | Epsilon   0.70 | Batch Size 15400 | Episode Return 1.32e+07 | Evaluation Score 1.02e+07
# Episode  78 | Epsilon   0.69 | Batch Size 15600 | Episode Return 1.64e+07 | Evaluation Score 8.98e+06
# Episode  79 | Epsilon   0.69 | Batch Size 15800 | Episode Return 1.45e+07 | Evaluation Score 1.05e+07
# Episode  80 | Epsilon   0.69 | Batch Size 16000 | Episode Return 2.63e+07 | Evaluation Score 8.98e+06
# Episode  81 | Epsilon   0.68 | Batch Size 16200 | Episode Return 1.33e+07 | Evaluation Score 1.03e+07
# Episode  82 | Epsilon   0.68 | Batch Size 16400 | Episode Return 9.90e+06 | Evaluation Score 1.03e+07
# Episode  83 | Epsilon   0.67 | Batch Size 16600 | Episode Return 1.36e+07 | Evaluation Score 8.98e+06
# Episode  84 | Epsilon   0.67 | Batch Size 16800 | Episode Return 1.58e+07 | Evaluation Score 1.03e+07
# Episode  85 | Epsilon   0.67 | Batch Size 17000 | Episode Return 1.53e+07 | Evaluation Score 1.03e+07
# Episode  86 | Epsilon   0.66 | Batch Size 17200 | Episode Return 1.34e+07 | Evaluation Score 1.03e+07
# Episode  87 | Epsilon   0.66 | Batch Size 17400 | Episode Return 1.69e+07 | Evaluation Score 9.39e+06
# Episode  88 | Epsilon   0.65 | Batch Size 17600 | Episode Return 1.92e+07 | Evaluation Score 8.56e+06
# Episode  89 | Epsilon   0.65 | Batch Size 17800 | Episode Return 1.87e+07 | Evaluation Score 9.02e+06
# Episode  90 | Epsilon   0.65 | Batch Size 18000 | Episode Return 1.81e+07 | Evaluation Score 9.48e+06
# Episode  91 | Epsilon   0.64 | Batch Size 18200 | Episode Return 4.34e+07 | Evaluation Score 1.03e+07
# Episode  92 | Epsilon   0.64 | Batch Size 18400 | Episode Return 4.01e+07 | Evaluation Score 1.03e+07
# Episode  93 | Epsilon   0.63 | Batch Size 18600 | Episode Return 2.94e+07 | Evaluation Score 1.13e+07
# Episode  94 | Epsilon   0.63 | Batch Size 18800 | Episode Return 1.24e+07 | Evaluation Score 1.11e+07
# Episode  95 | Epsilon   0.63 | Batch Size 19000 | Episode Return 2.56e+07 | Evaluation Score 1.13e+07
# Episode  96 | Epsilon   0.62 | Batch Size 19200 | Episode Return 4.00e+07 | Evaluation Score 1.07e+07
# Episode  97 | Epsilon   0.62 | Batch Size 19400 | Episode Return 1.85e+07 | Evaluation Score 9.39e+06
# Episode  98 | Epsilon   0.61 | Batch Size 19600 | Episode Return 2.38e+07 | Evaluation Score 1.05e+07
# Episode  99 | Epsilon   0.61 | Batch Size 19800 | Episode Return 2.94e+07 | Evaluation Score 9.39e+06
# Episode 100 | Epsilon   0.61 | Batch Size 20000 | Episode Return 2.60e+07 | Evaluation Score 1.05e+07
# Episode 101 | Epsilon   0.60 | Batch Size 20200 | Episode Return 2.42e+07 | Evaluation Score 1.09e+07
# Episode 102 | Epsilon   0.60 | Batch Size 20400 | Episode Return 2.88e+07 | Evaluation Score 1.14e+07
# Episode 103 | Epsilon   0.59 | Batch Size 20600 | Episode Return 2.63e+07 | Evaluation Score 1.09e+07
# Episode 104 | Epsilon   0.59 | Batch Size 20800 | Episode Return 3.40e+07 | Evaluation Score 9.34e+06
# Episode 105 | Epsilon   0.59 | Batch Size 21000 | Episode Return 1.70e+07 | Evaluation Score 9.34e+06
# Episode 106 | Epsilon   0.58 | Batch Size 21200 | Episode Return 3.37e+07 | Evaluation Score 9.39e+06
# Episode 107 | Epsilon   0.58 | Batch Size 21400 | Episode Return 3.42e+07 | Evaluation Score 9.34e+06
# Episode 108 | Epsilon   0.57 | Batch Size 21600 | Episode Return 2.00e+07 | Evaluation Score 9.34e+06
# Episode 109 | Epsilon   0.57 | Batch Size 21800 | Episode Return 2.01e+07 | Evaluation Score 1.09e+07
# Episode 110 | Epsilon   0.57 | Batch Size 22000 | Episode Return 1.85e+07 | Evaluation Score 1.09e+07
# Episode 111 | Epsilon   0.56 | Batch Size 22200 | Episode Return 3.47e+07 | Evaluation Score 1.07e+07
# Episode 112 | Epsilon   0.56 | Batch Size 22400 | Episode Return 2.14e+07 | Evaluation Score 1.07e+07
# Episode 113 | Epsilon   0.55 | Batch Size 22600 | Episode Return 2.82e+07 | Evaluation Score 1.06e+07
# Episode 114 | Epsilon   0.55 | Batch Size 22800 | Episode Return 3.35e+07 | Evaluation Score 1.06e+07
# Episode 115 | Epsilon   0.55 | Batch Size 23000 | Episode Return 2.70e+07 | Evaluation Score 1.07e+07
# Episode 116 | Epsilon   0.54 | Batch Size 23200 | Episode Return 2.35e+07 | Evaluation Score 1.09e+07
# Episode 117 | Epsilon   0.54 | Batch Size 23400 | Episode Return 1.71e+07 | Evaluation Score 1.09e+07
# Episode 118 | Epsilon   0.53 | Batch Size 23600 | Episode Return 4.98e+07 | Evaluation Score 9.24e+06
# Episode 119 | Epsilon   0.53 | Batch Size 23800 | Episode Return 1.96e+07 | Evaluation Score 1.00e+07
# Episode 120 | Epsilon   0.53 | Batch Size 24000 | Episode Return 4.81e+07 | Evaluation Score 1.00e+07
# Episode 121 | Epsilon   0.52 | Batch Size 24200 | Episode Return 4.95e+07 | Evaluation Score 1.09e+07
# Episode 122 | Epsilon   0.52 | Batch Size 24400 | Episode Return 2.23e+07 | Evaluation Score 1.09e+07
# Episode 123 | Epsilon   0.51 | Batch Size 24600 | Episode Return 4.94e+07 | Evaluation Score 1.09e+07
# Episode 124 | Epsilon   0.51 | Batch Size 24800 | Episode Return 3.18e+07 | Evaluation Score 9.34e+06
# Episode 125 | Epsilon   0.51 | Batch Size 25000 | Episode Return 3.40e+07 | Evaluation Score 1.16e+07
# Episode 126 | Epsilon   0.50 | Batch Size 25200 | Episode Return 1.87e+07 | Evaluation Score 1.23e+07
# Episode 127 | Epsilon   0.50 | Batch Size 25400 | Episode Return 4.52e+07 | Evaluation Score 1.24e+07
# Episode 128 | Epsilon   0.50 | Batch Size 25600 | Episode Return 1.80e+07 | Evaluation Score 1.16e+07
# Episode 129 | Epsilon   0.49 | Batch Size 25800 | Episode Return 2.30e+07 | Evaluation Score 1.09e+07
# Episode 130 | Epsilon   0.49 | Batch Size 26000 | Episode Return 5.03e+07 | Evaluation Score 1.09e+07
# Episode 131 | Epsilon   0.48 | Batch Size 26200 | Episode Return 3.55e+07 | Evaluation Score 1.09e+07
# Episode 132 | Epsilon   0.48 | Batch Size 26400 | Episode Return 3.16e+07 | Evaluation Score 1.09e+07
# Episode 133 | Epsilon   0.48 | Batch Size 26600 | Episode Return 3.65e+07 | Evaluation Score 1.17e+07
# Episode 134 | Epsilon   0.47 | Batch Size 26800 | Episode Return 7.09e+07 | Evaluation Score 1.18e+07
# Episode 135 | Epsilon   0.47 | Batch Size 27000 | Episode Return 2.51e+07 | Evaluation Score 1.17e+07
# Episode 136 | Epsilon   0.46 | Batch Size 27200 | Episode Return 3.00e+07 | Evaluation Score 1.16e+07
# Episode 137 | Epsilon   0.46 | Batch Size 27400 | Episode Return 3.57e+07 | Evaluation Score 1.15e+07
# Episode 138 | Epsilon   0.46 | Batch Size 27600 | Episode Return 4.16e+07 | Evaluation Score 1.09e+07
# Episode 139 | Epsilon   0.45 | Batch Size 27800 | Episode Return 2.89e+07 | Evaluation Score 1.15e+07
# Episode 140 | Epsilon   0.45 | Batch Size 28000 | Episode Return 3.08e+07 | Evaluation Score 1.00e+07
# Episode 141 | Epsilon   0.44 | Batch Size 28200 | Episode Return 4.29e+07 | Evaluation Score 1.16e+07
# Episode 142 | Epsilon   0.44 | Batch Size 28400 | Episode Return 9.15e+07 | Evaluation Score 1.16e+07
# Episode 143 | Epsilon   0.44 | Batch Size 28600 | Episode Return 5.94e+07 | Evaluation Score 1.16e+07
# Episode 144 | Epsilon   0.43 | Batch Size 28800 | Episode Return 8.06e+07 | Evaluation Score 1.16e+07
# Episode 145 | Epsilon   0.43 | Batch Size 29000 | Episode Return 4.57e+07 | Evaluation Score 1.16e+07
# Episode 146 | Epsilon   0.42 | Batch Size 29200 | Episode Return 2.97e+07 | Evaluation Score 1.14e+07
# Episode 147 | Epsilon   0.42 | Batch Size 29400 | Episode Return 6.77e+07 | Evaluation Score 1.16e+07
# Episode 148 | Epsilon   0.42 | Batch Size 29600 | Episode Return 3.73e+07 | Evaluation Score 1.25e+07
# Episode 149 | Epsilon   0.41 | Batch Size 29800 | Episode Return 6.88e+07 | Evaluation Score 1.33e+07
# Episode 150 | Epsilon   0.41 | Batch Size 30000 | Episode Return 6.74e+07 | Evaluation Score 1.27e+07
# Episode 151 | Epsilon   0.40 | Batch Size 30200 | Episode Return 3.25e+07 | Evaluation Score 8.02e+06
# Episode 152 | Epsilon   0.40 | Batch Size 30400 | Episode Return 6.52e+07 | Evaluation Score 9.59e+06
# Episode 153 | Epsilon   0.40 | Batch Size 30600 | Episode Return 3.14e+07 | Evaluation Score 1.16e+07
# Episode 154 | Epsilon   0.39 | Batch Size 30800 | Episode Return 6.08e+07 | Evaluation Score 1.16e+07
# Episode 155 | Epsilon   0.39 | Batch Size 31000 | Episode Return 6.20e+07 | Evaluation Score 1.16e+07
# Episode 156 | Epsilon   0.38 | Batch Size 31200 | Episode Return 6.28e+07 | Evaluation Score 1.12e+07
# Episode 157 | Epsilon   0.38 | Batch Size 31400 | Episode Return 7.55e+07 | Evaluation Score 1.16e+07
# Episode 158 | Epsilon   0.38 | Batch Size 31600 | Episode Return 4.33e+07 | Evaluation Score 1.48e+07
# Episode 159 | Epsilon   0.37 | Batch Size 31800 | Episode Return 1.39e+08 | Evaluation Score 1.33e+07
# Episode 160 | Epsilon   0.37 | Batch Size 32000 | Episode Return 5.71e+07 | Evaluation Score 1.25e+07
# Episode 161 | Epsilon   0.36 | Batch Size 32200 | Episode Return 1.55e+08 | Evaluation Score 1.16e+07
# Episode 162 | Epsilon   0.36 | Batch Size 32400 | Episode Return 1.05e+08 | Evaluation Score 1.09e+07
# Episode 163 | Epsilon   0.36 | Batch Size 32600 | Episode Return 5.76e+07 | Evaluation Score 1.49e+07
# Episode 164 | Epsilon   0.35 | Batch Size 32800 | Episode Return 5.66e+07 | Evaluation Score 1.33e+07
# Episode 165 | Epsilon   0.35 | Batch Size 33000 | Episode Return 3.30e+07 | Evaluation Score 1.27e+07
# Episode 166 | Epsilon   0.34 | Batch Size 33200 | Episode Return 1.31e+08 | Evaluation Score 1.63e+07
# Episode 167 | Epsilon   0.34 | Batch Size 33400 | Episode Return 3.26e+07 | Evaluation Score 1.57e+07
# Episode 168 | Epsilon   0.34 | Batch Size 33600 | Episode Return 1.99e+08 | Evaluation Score 1.54e+07
# Episode 169 | Epsilon   0.33 | Batch Size 33800 | Episode Return 1.36e+08 | Evaluation Score 1.43e+07
# Episode 170 | Epsilon   0.33 | Batch Size 34000 | Episode Return 4.18e+07 | Evaluation Score 1.34e+07
# Episode 171 | Epsilon   0.32 | Batch Size 34200 | Episode Return 1.42e+08 | Evaluation Score 1.55e+07
# Episode 172 | Epsilon   0.32 | Batch Size 34400 | Episode Return 1.02e+08 | Evaluation Score 2.72e+07
# Episode 173 | Epsilon   0.32 | Batch Size 34600 | Episode Return 1.49e+08 | Evaluation Score 2.72e+07
# Episode 174 | Epsilon   0.31 | Batch Size 34800 | Episode Return 1.44e+08 | Evaluation Score 1.57e+07
# Episode 175 | Epsilon   0.31 | Batch Size 35000 | Episode Return 8.90e+07 | Evaluation Score 2.72e+07
# Episode 176 | Epsilon   0.31 | Batch Size 35200 | Episode Return 9.67e+07 | Evaluation Score 2.72e+07
# Episode 177 | Epsilon   0.30 | Batch Size 35400 | Episode Return 3.39e+08 | Evaluation Score 2.73e+07
# Episode 178 | Epsilon   0.30 | Batch Size 35600 | Episode Return 2.28e+08 | Evaluation Score 1.77e+07
# Episode 179 | Epsilon   0.29 | Batch Size 35800 | Episode Return 3.32e+08 | Evaluation Score 1.77e+07
# Episode 180 | Epsilon   0.29 | Batch Size 36000 | Episode Return 1.15e+08 | Evaluation Score 1.76e+07
# Episode 181 | Epsilon   0.29 | Batch Size 36200 | Episode Return 2.49e+08 | Evaluation Score 1.76e+07
# Episode 182 | Epsilon   0.28 | Batch Size 36400 | Episode Return 1.69e+08 | Evaluation Score 2.02e+07
# Episode 183 | Epsilon   0.28 | Batch Size 36600 | Episode Return 8.43e+07 | Evaluation Score 2.33e+07
# Episode 184 | Epsilon   0.27 | Batch Size 36800 | Episode Return 1.72e+08 | Evaluation Score 2.73e+07
# Episode 185 | Epsilon   0.27 | Batch Size 37000 | Episode Return 1.44e+08 | Evaluation Score 2.73e+07
# Episode 186 | Epsilon   0.27 | Batch Size 37200 | Episode Return 1.99e+08 | Evaluation Score 2.73e+07
# Episode 187 | Epsilon   0.26 | Batch Size 37400 | Episode Return 5.15e+08 | Evaluation Score 2.73e+07
# Episode 188 | Epsilon   0.26 | Batch Size 37600 | Episode Return 9.03e+08 | Evaluation Score 2.06e+07
# Episode 189 | Epsilon   0.25 | Batch Size 37800 | Episode Return 1.83e+08 | Evaluation Score 1.65e+07
# Episode 190 | Epsilon   0.25 | Batch Size 38000 | Episode Return 2.33e+08 | Evaluation Score 2.33e+07
# Episode 191 | Epsilon   0.25 | Batch Size 38200 | Episode Return 2.37e+08 | Evaluation Score 2.33e+07
# Episode 192 | Epsilon   0.24 | Batch Size 38400 | Episode Return 4.20e+08 | Evaluation Score 2.72e+07
# Episode 193 | Epsilon   0.24 | Batch Size 38600 | Episode Return 3.94e+08 | Evaluation Score 2.45e+07
# Episode 194 | Epsilon   0.23 | Batch Size 38800 | Episode Return 1.61e+08 | Evaluation Score 2.45e+07
# Episode 195 | Epsilon   0.23 | Batch Size 39000 | Episode Return 1.34e+08 | Evaluation Score 2.45e+07
# Episode 196 | Epsilon   0.23 | Batch Size 39200 | Episode Return 1.66e+08 | Evaluation Score 2.92e+07
# Episode 197 | Epsilon   0.22 | Batch Size 39400 | Episode Return 6.04e+08 | Evaluation Score 2.92e+07
# Episode 198 | Epsilon   0.22 | Batch Size 39600 | Episode Return 2.47e+08 | Evaluation Score 2.45e+07
# Episode 199 | Epsilon   0.21 | Batch Size 39800 | Episode Return 2.39e+08 | Evaluation Score 2.45e+07
# Episode 200 | Epsilon   0.21 | Batch Size 40000 | Episode Return 1.82e+08 | Evaluation Score 2.45e+07
# Episode 201 | Epsilon   0.21 | Batch Size 40200 | Episode Return 2.25e+08 | Evaluation Score 1.61e+07
# Episode 202 | Epsilon   0.20 | Batch Size 40400 | Episode Return 6.13e+08 | Evaluation Score 2.79e+07
# Episode 203 | Epsilon   0.20 | Batch Size 40600 | Episode Return 7.42e+08 | Evaluation Score 2.53e+07
# Episode 204 | Epsilon   0.19 | Batch Size 40800 | Episode Return 2.13e+09 | Evaluation Score 2.53e+07
# Episode 205 | Epsilon   0.19 | Batch Size 41000 | Episode Return 4.14e+08 | Evaluation Score 1.65e+07
# Episode 206 | Epsilon   0.19 | Batch Size 41200 | Episode Return 4.36e+08 | Evaluation Score 2.02e+07
# Episode 207 | Epsilon   0.18 | Batch Size 41400 | Episode Return 8.77e+08 | Evaluation Score 2.02e+07
# Episode 208 | Epsilon   0.18 | Batch Size 41600 | Episode Return 1.34e+09 | Evaluation Score 1.94e+07
# Episode 209 | Epsilon   0.17 | Batch Size 41800 | Episode Return 2.51e+08 | Evaluation Score 1.79e+07
# Episode 210 | Epsilon   0.17 | Batch Size 42000 | Episode Return 3.21e+08 | Evaluation Score 1.94e+07
# Episode 211 | Epsilon   0.17 | Batch Size 42200 | Episode Return 3.95e+08 | Evaluation Score 1.94e+07
# Episode 212 | Epsilon   0.16 | Batch Size 42400 | Episode Return 1.96e+09 | Evaluation Score 1.64e+07
# Episode 213 | Epsilon   0.16 | Batch Size 42600 | Episode Return 9.32e+08 | Evaluation Score 1.71e+07
# Episode 214 | Epsilon   0.15 | Batch Size 42800 | Episode Return 1.26e+09 | Evaluation Score 1.64e+07
# Episode 215 | Epsilon   0.15 | Batch Size 43000 | Episode Return 9.38e+08 | Evaluation Score 1.74e+07
# Episode 216 | Epsilon   0.15 | Batch Size 43200 | Episode Return 1.65e+09 | Evaluation Score 1.56e+07
# Episode 217 | Epsilon   0.14 | Batch Size 43400 | Episode Return 3.23e+08 | Evaluation Score 1.55e+07
# Episode 218 | Epsilon   0.14 | Batch Size 43600 | Episode Return 1.62e+09 | Evaluation Score 1.43e+07
# Episode 219 | Epsilon   0.13 | Batch Size 43800 | Episode Return 4.47e+08 | Evaluation Score 1.81e+07
# Episode 220 | Epsilon   0.13 | Batch Size 44000 | Episode Return 3.56e+09 | Evaluation Score 1.81e+07
# Episode 221 | Epsilon   0.13 | Batch Size 44200 | Episode Return 5.06e+09 | Evaluation Score 1.52e+07
# Episode 222 | Epsilon   0.12 | Batch Size 44400 | Episode Return 4.07e+09 | Evaluation Score 1.74e+07
# Episode 223 | Epsilon   0.12 | Batch Size 44600 | Episode Return 4.37e+08 | Evaluation Score 1.74e+07
# Episode 224 | Epsilon   0.11 | Batch Size 44800 | Episode Return 5.60e+08 | Evaluation Score 1.74e+07
# Episode 225 | Epsilon   0.11 | Batch Size 45000 | Episode Return 5.20e+09 | Evaluation Score 1.74e+07
# Episode 226 | Epsilon   0.11 | Batch Size 45200 | Episode Return 4.87e+09 | Evaluation Score 1.34e+07
# Episode 227 | Epsilon   0.10 | Batch Size 45400 | Episode Return 4.61e+09 | Evaluation Score 1.46e+07
# Episode 228 | Epsilon   0.10 | Batch Size 45600 | Episode Return 1.00e+08 | Evaluation Score 1.96e+07
# Episode 229 | Epsilon   0.10 | Batch Size 45800 | Episode Return 4.92e+09 | Evaluation Score 1.86e+07
# Episode 230 | Epsilon   0.09 | Batch Size 46000 | Episode Return 6.22e+09 | Evaluation Score 2.28e+07
# Episode 231 | Epsilon   0.09 | Batch Size 46200 | Episode Return 9.52e+09 | Evaluation Score 2.06e+07
# Episode 232 | Epsilon   0.08 | Batch Size 46400 | Episode Return 1.03e+10 | Evaluation Score 1.96e+07
# Episode 233 | Epsilon   0.08 | Batch Size 46600 | Episode Return 7.81e+09 | Evaluation Score 1.47e+07
# Episode 234 | Epsilon   0.08 | Batch Size 46800 | Episode Return 5.38e+07 | Evaluation Score 1.47e+07
# Episode 235 | Epsilon   0.07 | Batch Size 47000 | Episode Return 4.21e+08 | Evaluation Score 1.47e+07
# Episode 236 | Epsilon   0.07 | Batch Size 47200 | Episode Return 1.24e+10 | Evaluation Score 2.11e+07
# Episode 237 | Epsilon   0.06 | Batch Size 47400 | Episode Return 1.26e+10 | Evaluation Score 2.08e+07
# Episode 238 | Epsilon   0.06 | Batch Size 47600 | Episode Return 6.73e+09 | Evaluation Score 1.84e+07
# Episode 239 | Epsilon   0.06 | Batch Size 47800 | Episode Return 6.35e+09 | Evaluation Score 2.17e+07
# Episode 240 | Epsilon   0.05 | Batch Size 48000 | Episode Return 1.27e+10 | Evaluation Score 2.17e+07
# Episode 241 | Epsilon   0.05 | Batch Size 48200 | Episode Return 1.43e+10 | Evaluation Score 2.05e+07
# Episode 242 | Epsilon   0.04 | Batch Size 48400 | Episode Return 5.80e+09 | Evaluation Score 2.05e+07
# Episode 243 | Epsilon   0.04 | Batch Size 48600 | Episode Return 1.34e+10 | Evaluation Score 2.07e+07
# Episode 244 | Epsilon   0.04 | Batch Size 48800 | Episode Return 1.80e+10 | Evaluation Score 2.07e+07
# Episode 245 | Epsilon   0.03 | Batch Size 49000 | Episode Return 1.47e+10 | Evaluation Score 2.07e+07
# Episode 246 | Epsilon   0.03 | Batch Size 49200 | Episode Return 1.03e+10 | Evaluation Score 2.13e+07
# Episode 247 | Epsilon   0.02 | Batch Size 49400 | Episode Return 9.15e+08 | Evaluation Score 2.02e+07
# Episode 248 | Epsilon   0.02 | Batch Size 49600 | Episode Return 1.55e+09 | Evaluation Score 2.58e+07
# Episode 249 | Epsilon   0.02 | Batch Size 49800 | Episode Return 1.57e+08 | Evaluation Score 2.11e+07
# Episode 250 | Epsilon   0.01 | Batch Size 50000 | Episode Return 5.22e+09 | Evaluation Score 2.50e+07
# Episode 251 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.43e+10 | Evaluation Score 3.03e+07
# Episode 252 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.43e+10 | Evaluation Score 2.67e+07
# Episode 253 | Epsilon   0.01 | Batch Size 50000 | Episode Return 5.79e+07 | Evaluation Score 3.03e+07
# Episode 254 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.81e+08 | Evaluation Score 2.30e+07
# Episode 255 | Epsilon   0.01 | Batch Size 50000 | Episode Return 4.16e+07 | Evaluation Score 2.94e+07
# Episode 256 | Epsilon   0.01 | Batch Size 50000 | Episode Return 3.16e+07 | Evaluation Score 1.92e+07
# Episode 257 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.11e+10 | Evaluation Score 1.54e+07
# Episode 258 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.59e+10 | Evaluation Score 1.64e+07
# Episode 259 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.00e+07 | Evaluation Score 1.89e+07
# Episode 260 | Epsilon   0.01 | Batch Size 50000 | Episode Return 3.08e+07 | Evaluation Score 2.20e+07
# Episode 261 | Epsilon   0.01 | Batch Size 50000 | Episode Return 3.69e+07 | Evaluation Score 2.20e+07
# Episode 262 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.57e+10 | Evaluation Score 2.37e+07
# Episode 263 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.73e+10 | Evaluation Score 2.20e+07
# Episode 264 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.80e+08 | Evaluation Score 1.00e+07
# Episode 265 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.88e+10 | Evaluation Score 1.60e+07
# Episode 266 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.72e+10 | Evaluation Score 2.21e+07
# Episode 267 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.61e+10 | Evaluation Score 1.70e+07
# Episode 268 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.38e+10 | Evaluation Score 1.54e+07
# Episode 269 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.92e+07 | Evaluation Score 2.31e+07
# Episode 270 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.59e+10 | Evaluation Score 2.20e+07
# Episode 271 | Epsilon   0.01 | Batch Size 50000 | Episode Return 4.95e+07 | Evaluation Score 1.66e+07
# Episode 272 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.20e+07 | Evaluation Score 1.48e+07
# Episode 273 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.73e+10 | Evaluation Score 1.70e+07
# Episode 274 | Epsilon   0.01 | Batch Size 50000 | Episode Return 3.79e+07 | Evaluation Score 1.72e+07
# Episode 275 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.83e+10 | Evaluation Score 1.70e+07
# Episode 276 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.20e+10 | Evaluation Score 1.70e+07
# Episode 277 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.59e+10 | Evaluation Score 1.80e+07
# Episode 278 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.09e+08 | Evaluation Score 6.13e+06
# Episode 279 | Epsilon   0.01 | Batch Size 50000 | Episode Return 6.77e+06 | Evaluation Score 6.11e+06
# Episode 280 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.54e+10 | Evaluation Score 6.85e+06
# Episode 281 | Epsilon   0.01 | Batch Size 50000 | Episode Return 5.80e+07 | Evaluation Score 1.39e+07
# Episode 282 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.21e+07 | Evaluation Score 1.07e+07
# Episode 283 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.59e+10 | Evaluation Score 8.37e+06
# Episode 284 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.02e+10 | Evaluation Score 8.76e+06
# Episode 285 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.78e+07 | Evaluation Score 9.52e+06
# Episode 286 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.35e+10 | Evaluation Score 2.50e+07
# Episode 287 | Epsilon   0.01 | Batch Size 50000 | Episode Return 4.16e+07 | Evaluation Score 2.43e+07
# Episode 288 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.79e+10 | Evaluation Score 1.00e+07
# Episode 289 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.52e+10 | Evaluation Score 1.08e+07
# Episode 290 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.55e+07 | Evaluation Score 1.05e+07
# Episode 291 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.78e+07 | Evaluation Score 9.31e+06
# Episode 292 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.79e+07 | Evaluation Score 1.13e+07
# Episode 293 | Epsilon   0.01 | Batch Size 50000 | Episode Return 3.29e+07 | Evaluation Score 2.41e+07
# Episode 294 | Epsilon   0.01 | Batch Size 50000 | Episode Return 3.54e+07 | Evaluation Score 9.59e+06
# Episode 295 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.25e+10 | Evaluation Score 3.23e+07
# Episode 296 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.68e+10 | Evaluation Score 1.31e+07
# Episode 297 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.70e+10 | Evaluation Score 1.11e+07
# Episode 298 | Epsilon   0.01 | Batch Size 50000 | Episode Return 5.62e+09 | Evaluation Score 9.72e+07
# Episode 299 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.54e+10 | Evaluation Score 6.26e+07
# Episode 300 | Epsilon   0.01 | Batch Size 50000 | Episode Return 4.85e+09 | Evaluation Score 6.70e+07
# Episode 301 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.44e+10 | Evaluation Score 9.66e+07
# Episode 302 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.57e+10 | Evaluation Score 9.05e+07
# Episode 303 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.26e+10 | Evaluation Score 9.08e+07
# Episode 304 | Epsilon   0.01 | Batch Size 50000 | Episode Return 9.34e+09 | Evaluation Score 6.95e+07
# Episode 305 | Epsilon   0.01 | Batch Size 50000 | Episode Return 8.10e+07 | Evaluation Score 9.31e+07
# Episode 306 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.69e+10 | Evaluation Score 2.16e+07
# Episode 307 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.30e+10 | Evaluation Score 2.16e+07
# Episode 308 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.45e+10 | Evaluation Score 9.32e+07
# Episode 309 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.83e+08 | Evaluation Score 6.95e+07
# Episode 310 | Epsilon   0.01 | Batch Size 50000 | Episode Return 7.73e+07 | Evaluation Score 8.57e+07
# Episode 311 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.35e+10 | Evaluation Score 1.02e+08
# Episode 312 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.87e+10 | Evaluation Score 5.65e+07
# Episode 313 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.76e+10 | Evaluation Score 1.07e+08
# Episode 314 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.07e+08 | Evaluation Score 1.03e+08
# Episode 315 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.08e+08 | Evaluation Score 1.38e+08
# Episode 316 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.11e+08 | Evaluation Score 9.90e+07
# Episode 317 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.70e+08 | Evaluation Score 8.87e+07
# Episode 318 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.31e+08 | Evaluation Score 7.87e+07
# Episode 319 | Epsilon   0.01 | Batch Size 50000 | Episode Return 7.05e+07 | Evaluation Score 1.30e+08
# Episode 320 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.46e+10 | Evaluation Score 7.71e+07
# Episode 321 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.85e+10 | Evaluation Score 1.25e+08
# Episode 322 | Epsilon   0.01 | Batch Size 50000 | Episode Return 3.14e+10 | Evaluation Score 1.36e+08
# Episode 323 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.64e+10 | Evaluation Score 1.11e+08
# Episode 324 | Epsilon   0.01 | Batch Size 50000 | Episode Return 3.07e+10 | Evaluation Score 1.15e+08
# Episode 325 | Epsilon   0.01 | Batch Size 50000 | Episode Return 8.95e+07 | Evaluation Score 1.18e+08
# Episode 326 | Epsilon   0.01 | Batch Size 50000 | Episode Return 3.20e+10 | Evaluation Score 1.24e+08
# Episode 327 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.79e+10 | Evaluation Score 1.35e+08
# Episode 328 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.36e+10 | Evaluation Score 3.80e+07
# Episode 329 | Epsilon   0.01 | Batch Size 50000 | Episode Return 4.02e+07 | Evaluation Score 3.67e+07
# Episode 330 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.54e+10 | Evaluation Score 4.51e+07
# Episode 331 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.86e+10 | Evaluation Score 5.11e+07
# Episode 332 | Epsilon   0.01 | Batch Size 50000 | Episode Return 4.86e+09 | Evaluation Score 1.47e+08
# Episode 333 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.52e+09 | Evaluation Score 3.74e+07
# Episode 334 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.25e+10 | Evaluation Score 3.63e+07
# Episode 335 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.82e+10 | Evaluation Score 4.64e+07
# Episode 336 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.98e+08 | Evaluation Score 1.50e+08
# Episode 337 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.73e+10 | Evaluation Score 2.02e+08
# Episode 338 | Epsilon   0.01 | Batch Size 50000 | Episode Return 8.57e+09 | Evaluation Score 4.56e+07
# Episode 339 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.59e+10 | Evaluation Score 4.54e+07
# Episode 340 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.37e+10 | Evaluation Score 5.28e+07
# Episode 341 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.68e+10 | Evaluation Score 6.37e+07
# Episode 342 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.52e+10 | Evaluation Score 4.79e+08
# Episode 343 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.22e+10 | Evaluation Score 1.73e+08
# Episode 344 | Epsilon   0.01 | Batch Size 50000 | Episode Return 5.40e+09 | Evaluation Score 2.28e+08
# Episode 345 | Epsilon   0.01 | Batch Size 50000 | Episode Return 3.05e+10 | Evaluation Score 2.02e+08
# Episode 346 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.79e+10 | Evaluation Score 1.25e+08
# Episode 347 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.97e+10 | Evaluation Score 1.92e+08
# Episode 348 | Epsilon   0.01 | Batch Size 50000 | Episode Return 3.19e+10 | Evaluation Score 1.87e+08
# Episode 349 | Epsilon   0.01 | Batch Size 50000 | Episode Return 8.73e+09 | Evaluation Score 2.12e+08
# Episode 350 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.45e+08 | Evaluation Score 2.31e+08
# Episode 351 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.70e+10 | Evaluation Score 3.10e+08
# Episode 352 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.11e+10 | Evaluation Score 1.84e+09
# Episode 353 | Epsilon   0.01 | Batch Size 50000 | Episode Return 3.06e+10 | Evaluation Score 2.95e+09
# Episode 354 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.29e+10 | Evaluation Score 3.09e+08
# Episode 355 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.55e+10 | Evaluation Score 1.73e+09
# Episode 356 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.51e+08 | Evaluation Score 1.38e+09
# Episode 357 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.84e+10 | Evaluation Score 4.80e+08
# Episode 358 | Epsilon   0.01 | Batch Size 50000 | Episode Return 8.94e+09 | Evaluation Score 1.32e+10
# Episode 359 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.67e+08 | Evaluation Score 2.98e+09
# Episode 360 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.27e+10 | Evaluation Score 8.04e+09
# Episode 361 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.24e+10 | Evaluation Score 3.19e+08
# Episode 362 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.48e+08 | Evaluation Score 2.66e+08
# Episode 363 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.26e+10 | Evaluation Score 2.20e+08
# Episode 364 | Epsilon   0.01 | Batch Size 50000 | Episode Return 3.07e+10 | Evaluation Score 2.36e+08
# Episode 365 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.04e+09 | Evaluation Score 1.20e+08
# Episode 366 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.77e+10 | Evaluation Score 4.84e+09
# Episode 367 | Epsilon   0.01 | Batch Size 50000 | Episode Return 3.18e+10 | Evaluation Score 3.15e+09
# Episode 368 | Epsilon   0.01 | Batch Size 50000 | Episode Return 3.87e+09 | Evaluation Score 1.39e+09
# Episode 369 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.95e+10 | Evaluation Score 8.02e+09
# Episode 370 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.03e+10 | Evaluation Score 6.07e+09
# Episode 371 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.52e+10 | Evaluation Score 2.74e+08
# Episode 372 | Epsilon   0.01 | Batch Size 50000 | Episode Return 3.31e+10 | Evaluation Score 1.36e+08
# Episode 373 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.72e+10 | Evaluation Score 1.53e+08
# Episode 374 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.09e+10 | Evaluation Score 1.63e+08
# Episode 375 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.87e+10 | Evaluation Score 1.39e+08
# Episode 376 | Epsilon   0.01 | Batch Size 50000 | Episode Return 3.90e+08 | Evaluation Score 1.76e+08
# Episode 377 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.95e+10 | Evaluation Score 1.70e+08
# Episode 378 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.42e+10 | Evaluation Score 2.04e+08
# Episode 379 | Epsilon   0.01 | Batch Size 50000 | Episode Return 3.41e+09 | Evaluation Score 2.57e+08
# Episode 380 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.97e+10 | Evaluation Score 3.87e+08
# Episode 381 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.15e+10 | Evaluation Score 1.20e+08
# Episode 382 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.18e+08 | Evaluation Score 1.14e+08
# Episode 383 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.34e+09 | Evaluation Score 1.80e+08
# Episode 384 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.77e+10 | Evaluation Score 8.35e+09
# Episode 385 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.56e+10 | Evaluation Score 2.51e+08
# Episode 386 | Epsilon   0.01 | Batch Size 50000 | Episode Return 3.21e+10 | Evaluation Score 7.04e+08
# Episode 387 | Epsilon   0.01 | Batch Size 50000 | Episode Return 9.95e+09 | Evaluation Score 9.42e+09
# Episode 388 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.97e+10 | Evaluation Score 1.76e+07
# Episode 389 | Epsilon   0.01 | Batch Size 50000 | Episode Return 7.80e+07 | Evaluation Score 1.14e+08
# Episode 390 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.20e+10 | Evaluation Score 2.34e+07
# Episode 391 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.73e+10 | Evaluation Score 6.59e+09
# Episode 392 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.24e+10 | Evaluation Score 6.68e+09
# Episode 393 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.39e+10 | Evaluation Score 2.34e+07
# Episode 394 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.55e+10 | Evaluation Score 2.34e+07
# Episode 395 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.59e+10 | Evaluation Score 2.34e+07
# Episode 396 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.44e+10 | Evaluation Score 6.52e+07
# Episode 397 | Epsilon   0.01 | Batch Size 50000 | Episode Return 3.66e+07 | Evaluation Score 4.07e+07
# Episode 398 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.60e+07 | Evaluation Score 1.60e+09
# Episode 399 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.49e+10 | Evaluation Score 2.90e+08
# Episode 400 | Epsilon   0.01 | Batch Size 50000 | Episode Return 4.64e+07 | Evaluation Score 6.92e+08
# Episode 401 | Epsilon   0.01 | Batch Size 50000 | Episode Return 5.46e+07 | Evaluation Score 1.68e+07
# Episode 402 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.23e+07 | Evaluation Score 5.58e+07
# Episode 403 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.09e+10 | Evaluation Score 4.59e+07
# Episode 404 | Epsilon   0.01 | Batch Size 50000 | Episode Return 5.26e+07 | Evaluation Score 5.34e+07
# Episode 405 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.34e+10 | Evaluation Score 4.78e+07
# Episode 406 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.06e+10 | Evaluation Score 8.76e+09
# Episode 407 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.94e+10 | Evaluation Score 6.53e+09
# Episode 408 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.82e+10 | Evaluation Score 4.32e+09
# Episode 409 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.64e+10 | Evaluation Score 3.36e+07
# Episode 410 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.16e+10 | Evaluation Score 6.53e+08
# Episode 411 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.81e+07 | Evaluation Score 7.27e+07
# Episode 412 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.28e+10 | Evaluation Score 4.44e+07
# Episode 413 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.82e+10 | Evaluation Score 9.86e+07
# Episode 414 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.04e+10 | Evaluation Score 7.76e+07
# Episode 415 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.23e+07 | Evaluation Score 4.53e+07
# Episode 416 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.79e+08 | Evaluation Score 7.74e+09
# Episode 417 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.85e+10 | Evaluation Score 8.71e+09
# Episode 418 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.07e+10 | Evaluation Score 5.50e+09
# Episode 419 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.36e+10 | Evaluation Score 8.51e+09
# Episode 420 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.63e+09 | Evaluation Score 5.44e+09
# Episode 421 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.43e+10 | Evaluation Score 5.43e+09
# Episode 422 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.63e+10 | Evaluation Score 6.30e+09
# Episode 423 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.89e+10 | Evaluation Score 8.57e+07
# Episode 424 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.34e+07 | Evaluation Score 5.59e+07
# Episode 425 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.12e+10 | Evaluation Score 5.59e+07
# Episode 426 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.32e+10 | Evaluation Score 2.32e+08
# Episode 427 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.62e+08 | Evaluation Score 7.87e+07
# Episode 428 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.72e+10 | Evaluation Score 4.18e+07
# Episode 429 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.41e+07 | Evaluation Score 5.28e+07
# Episode 430 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.80e+07 | Evaluation Score 3.89e+07
# Episode 431 | Epsilon   0.01 | Batch Size 50000 | Episode Return 9.07e+07 | Evaluation Score 7.11e+07
# Episode 432 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.18e+08 | Evaluation Score 6.00e+07
# Episode 433 | Epsilon   0.01 | Batch Size 50000 | Episode Return 7.71e+06 | Evaluation Score 3.16e+07
# Episode 434 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.49e+07 | Evaluation Score 1.15e+07
# Episode 435 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.82e+06 | Evaluation Score 2.49e+07
# Episode 436 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.45e+10 | Evaluation Score 2.85e+07
# Episode 437 | Epsilon   0.01 | Batch Size 50000 | Episode Return 4.81e+06 | Evaluation Score 4.23e+07
# Episode 438 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.86e+07 | Evaluation Score 5.18e+07
# Episode 439 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.82e+09 | Evaluation Score 6.51e+07
# Episode 440 | Epsilon   0.01 | Batch Size 50000 | Episode Return 5.71e+08 | Evaluation Score 4.45e+07
# Episode 441 | Epsilon   0.01 | Batch Size 50000 | Episode Return 4.22e+07 | Evaluation Score 2.58e+07
# Episode 442 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.81e+10 | Evaluation Score 5.36e+07
# Episode 443 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.04e+10 | Evaluation Score 3.86e+07
# Episode 444 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.55e+07 | Evaluation Score 3.83e+07
# Episode 445 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.73e+10 | Evaluation Score 2.37e+07
# Episode 446 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.52e+10 | Evaluation Score 5.30e+07
# Episode 447 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.92e+10 | Evaluation Score 3.82e+07
# Episode 448 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.87e+07 | Evaluation Score 5.20e+07
# Episode 449 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.57e+10 | Evaluation Score 3.77e+07
# Episode 450 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.65e+10 | Evaluation Score 3.87e+07
# Episode 451 | Epsilon   0.01 | Batch Size 50000 | Episode Return 3.66e+07 | Evaluation Score 5.58e+08
# Episode 452 | Epsilon   0.01 | Batch Size 50000 | Episode Return 3.02e+10 | Evaluation Score 4.22e+07
# Episode 453 | Epsilon   0.01 | Batch Size 50000 | Episode Return 3.26e+10 | Evaluation Score 2.51e+07
# Episode 454 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.43e+07 | Evaluation Score 2.67e+07
# Episode 455 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.09e+10 | Evaluation Score 2.15e+07
# Episode 456 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.53e+07 | Evaluation Score 2.47e+07
# Episode 457 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.36e+10 | Evaluation Score 3.25e+07
# Episode 458 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.86e+10 | Evaluation Score 3.54e+07
# Episode 459 | Epsilon   0.01 | Batch Size 50000 | Episode Return 3.76e+07 | Evaluation Score 2.12e+07
# Episode 460 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.11e+08 | Evaluation Score 3.40e+07
# Episode 461 | Epsilon   0.01 | Batch Size 50000 | Episode Return 5.36e+09 | Evaluation Score 2.74e+07
# Episode 462 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.16e+08 | Evaluation Score 2.79e+07
# Episode 463 | Epsilon   0.01 | Batch Size 50000 | Episode Return 6.04e+07 | Evaluation Score 2.82e+07
# Episode 464 | Epsilon   0.01 | Batch Size 50000 | Episode Return 3.08e+10 | Evaluation Score 2.77e+07
# Episode 465 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.01e+07 | Evaluation Score 2.41e+07
# Episode 466 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.19e+10 | Evaluation Score 3.37e+07
# Episode 467 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.72e+07 | Evaluation Score 3.37e+07
# Episode 468 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.36e+10 | Evaluation Score 3.01e+07
# Episode 469 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.24e+08 | Evaluation Score 2.91e+07
# Episode 470 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.39e+10 | Evaluation Score 3.34e+07
# Episode 471 | Epsilon   0.01 | Batch Size 50000 | Episode Return 8.85e+07 | Evaluation Score 2.15e+07
# Episode 472 | Epsilon   0.01 | Batch Size 50000 | Episode Return 6.18e+09 | Evaluation Score 2.55e+07
# Episode 473 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.23e+10 | Evaluation Score 1.88e+07
# Episode 474 | Epsilon   0.01 | Batch Size 50000 | Episode Return 3.71e+07 | Evaluation Score 3.43e+07
# Episode 475 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.67e+07 | Evaluation Score 1.64e+07
# Episode 476 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.06e+07 | Evaluation Score 2.61e+07
# Episode 477 | Epsilon   0.01 | Batch Size 50000 | Episode Return 7.11e+06 | Evaluation Score 1.47e+07
# Episode 478 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.61e+07 | Evaluation Score 2.99e+07
# Episode 479 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.63e+10 | Evaluation Score 2.87e+07
# Episode 480 | Epsilon   0.01 | Batch Size 50000 | Episode Return 5.09e+07 | Evaluation Score 2.12e+07
# Episode 481 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.72e+10 | Evaluation Score 2.36e+07
# Episode 482 | Epsilon   0.01 | Batch Size 50000 | Episode Return 6.37e+07 | Evaluation Score 2.41e+07
# Episode 483 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.75e+10 | Evaluation Score 1.86e+07
# Episode 484 | Epsilon   0.01 | Batch Size 50000 | Episode Return 4.28e+07 | Evaluation Score 1.98e+07
# Episode 485 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.31e+10 | Evaluation Score 1.94e+07
# Episode 486 | Epsilon   0.01 | Batch Size 50000 | Episode Return 4.31e+09 | Evaluation Score 1.51e+07
# Episode 487 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.58e+10 | Evaluation Score 1.54e+07
# Episode 488 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.84e+10 | Evaluation Score 1.45e+07
# Episode 489 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.05e+07 | Evaluation Score 2.15e+07
# Episode 490 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.92e+07 | Evaluation Score 1.47e+07
# Episode 491 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.75e+07 | Evaluation Score 1.54e+07
# Episode 492 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.25e+10 | Evaluation Score 1.11e+07
# Episode 493 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.75e+10 | Evaluation Score 1.61e+07
# Episode 494 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.83e+10 | Evaluation Score 2.71e+07
# Episode 495 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.69e+10 | Evaluation Score 1.77e+07
# Episode 496 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.13e+07 | Evaluation Score 1.85e+07
# Episode 497 | Epsilon   0.01 | Batch Size 50000 | Episode Return 7.99e+06 | Evaluation Score 1.49e+07
# Episode 498 | Epsilon   0.01 | Batch Size 50000 | Episode Return 2.20e+10 | Evaluation Score 1.86e+07
# Episode 499 | Epsilon   0.01 | Batch Size 50000 | Episode Return 1.45e+10 | Evaluation Score 1.99e+07
# Episode 500 | Epsilon   0.01 | Batch Size 50000 | Episode Return 3.20e+10 | Evaluation Score 2.26e+07
# Score agent: 13189289027.606344
# Score agent with domain randomization: 23811818356.48135
